# %% [markdown]
# <a href="https://colab.research.google.com/github/agarwalprashant/1984/blob/master/Timeseries_Analysis_of.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/AAPL.csv',parse_dates=['Date'],index_col="Date")

# %%
df.sample(10)
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 1995-09-22   0.329241   0.332589   0.324777   0.330915   0.282474  398641600
# 2002-04-04   0.422679   0.447321   0.422679   0.444643   0.380736  338497600
# 2005-11-29   2.499643   2.510714   2.405357   2.432143   2.082582  891433200
# 2013-07-09  14.771429  15.125000  14.656429  15.083929  13.193379  352584400
# 1990-01-10   0.335938   0.335938   0.319196   0.321429   0.257149  199718400
# 2017-08-16  40.485001  40.627499  40.037498  40.237499  38.297245  110686400
# 1984-04-05   0.109375   0.111049   0.107701   0.107701   0.084184   82812800
# 2020-04-23  68.967499  70.437500  68.717499  68.757500  67.825500  124814400
# 1993-07-14   0.328125   0.334821   0.319196   0.332589   0.275451  246299200
# 2013-05-23  15.569643  15.934286  15.563929  15.790714  13.811582  353021200

# %%
# size of data
df.shape
# Out:
# (10409, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10409 entries, 1980-12-12 to 2022-03-24
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       10409 non-null  float64
#  1   High       10409 non-null  float64
#  2   Low        10409 non-null  float64
#  3   Close      10409 non-null  float64
#  4   Adj Close  10409 non-null  float64
#  5   Volume     10409 non-null  int64
# dtypes: float64(5), int64(1)
# memory usage: 569.2 KB

# %%
df.index # its a DatetimeIndex Object
# Out:
# DatetimeIndex(['1980-12-12', '1980-12-15', '1980-12-16', '1980-12-17',
#                '1980-12-18', '1980-12-19', '1980-12-22', '1980-12-23',
#                '1980-12-24', '1980-12-26',
#                ...
#                '2022-03-11', '2022-03-14', '2022-03-15', '2022-03-16',
#                '2022-03-17', '2022-03-18', '2022-03-21', '2022-03-22',
#                '2022-03-23', '2022-03-24'],
#               dtype='datetime64[ns]', name='Date', length=10409, freq=None)

# %%
# fetch a specific date
df.loc['2022-03-17']
# Out:
# Open         1.586100e+02
# High         1.610000e+02
# Low          1.576300e+02
# Close        1.606200e+02
# Adj Close    1.606200e+02
# Volume       7.561540e+07
# Name: 2022-03-17 00:00:00, dtype: float64

# %%
# partial indexing -> select a particular year/month
df.loc['2021']
df.loc['2021-01']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-04  133.520004  133.610001  126.760002  129.410004  128.453430
# 2021-01-05  128.889999  131.740005  128.429993  131.009995  130.041611
# 2021-01-06  127.720001  131.050003  126.379997  126.599998  125.664207
# 2021-01-07  128.360001  131.630005  127.860001  130.919998  129.952286
# 2021-01-08  132.429993  132.630005  130.229996  132.050003  131.073944
# 2021-01-11  129.190002  130.169998  128.500000  128.979996  128.026611
# 2021-01-12  128.500000  129.690002  126.860001  128.800003  127.847954
# 2021-01-13  128.759995  131.449997  128.490005  130.889999  129.922501
# 2021-01-14  130.800003  131.000000  128.759995  128.910004  127.957138
# 2021-01-15  128.779999  130.220001  127.000000  127.139999  126.200218
# 2021-01-19  127.779999  128.710007  126.940002  127.830002  126.885132
# 2021-01-20  128.660004  132.490005  128.550003  132.029999  131.054092
# ...

# %%
# create year month-name and day-name
df.index
# Out:
# DatetimeIndex(['1980-12-12', '1980-12-15', '1980-12-16', '1980-12-17',
#                '1980-12-18', '1980-12-19', '1980-12-22', '1980-12-23',
#                '1980-12-24', '1980-12-26',
#                ...
#                '2022-03-11', '2022-03-14', '2022-03-15', '2022-03-16',
#                '2022-03-17', '2022-03-18', '2022-03-21', '2022-03-22',
#                '2022-03-23', '2022-03-24'],
#               dtype='datetime64[ns]', name='Date', length=10409, freq=None)

# %%
df['month_name'] = df.index.month_name()
df['weekday_name'] = df.index.day_name()
df['quarter'] = df.index.quarter

# %%
df['year'] = df.index.year

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-12    0.128348    0.128906    0.128348    0.128348    0.100323
# 1980-12-15    0.122210    0.122210    0.121652    0.121652    0.095089
# 1980-12-16    0.113281    0.113281    0.112723    0.112723    0.088110
# 1980-12-17    0.115513    0.116071    0.115513    0.115513    0.090291
# 1980-12-18    0.118862    0.119420    0.118862    0.118862    0.092908
# ...                ...         ...         ...         ...         ...
# 2022-03-18  160.509995  164.479996  159.759995  163.979996  163.979996
# 2022-03-21  163.509995  166.350006  163.009995  165.380005  165.380005
# 2022-03-22  165.509995  169.419998  164.910004  168.820007  168.820007
# 2022-03-23  167.990005  172.639999  167.649994  170.210007  170.210007
# 2022-03-24  171.059998  174.139999  170.210007  174.070007  174.070007
#
#                Volume month_name weekday_name  quarter  year
# Date
# ...

# %%
df['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# using matplotlib
plt.figure(figsize=(12,6))
plt.plot('Close',data=df)

# %%
# slicing
df.loc['1980-12-12':'1981-01-12']
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 1980-12-12  0.128348  0.128906  0.128348  0.128348   0.100323  469033600
# 1980-12-15  0.122210  0.122210  0.121652  0.121652   0.095089  175884800
# 1980-12-16  0.113281  0.113281  0.112723  0.112723   0.088110  105728000
# 1980-12-17  0.115513  0.116071  0.115513  0.115513   0.090291   86441600
# 1980-12-18  0.118862  0.119420  0.118862  0.118862   0.092908   73449600
# 1980-12-19  0.126116  0.126674  0.126116  0.126116   0.098578   48630400
# 1980-12-22  0.132254  0.132813  0.132254  0.132254   0.103376   37363200
# 1980-12-23  0.137835  0.138393  0.137835  0.137835   0.107739   46950400
# 1980-12-24  0.145089  0.145647  0.145089  0.145089   0.113409   48003200
# 1980-12-26  0.158482  0.159040  0.158482  0.158482   0.123877   55574400
# 1980-12-29  0.160714  0.161272  0.160714  0.160714   0.125622   93161600
# 1980-12-30  0.157366  0.157366  0.156808  0.156808   0.122569   68880000
# ...

# %%
# was 1981-01-04 and 1981-01-03 not a business day
pd.Timestamp('1981-01-03').day_of_week >=5
# Out:
# True

# %%
pd.Timestamp('1981-01-04').day_of_week >=5
# Out:
# True

# %%
# plot for a particular year/month/week
df.loc['2002']['Close'].plot()
# Out:
# <Axes: xlabel='Date'>
